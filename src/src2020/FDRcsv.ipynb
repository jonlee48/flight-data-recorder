# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

# %%
df_flight_data = pd.read_csv(r'/Users/Jonathan Lee/MyFiles/FlightRecorder2/flight_data_test_0.csv')

# %%
df_flight_data.plot()

# %%
df_flight_data.head()
# Out:
#      time  heading  pitch  roll   temp  pressure  altitude
# 0  184.92     3.20  -1.60  1.44  77.15   1006.03      0.09
# 1  184.96     2.95  -1.79  1.80  77.15   1006.02      0.06
# 2  185.01     2.95  -1.82  1.79  77.13   1006.03      0.01
# 3  185.05     2.95  -1.84  1.76  77.13   1006.03      0.06
# 4  185.09     2.96  -1.84  1.81  77.14   1006.03      0.05
